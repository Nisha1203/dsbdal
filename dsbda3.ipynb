# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 145  146            6.7           3.0            5.2           2.3  \
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe(include='object')
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
df_groupby=df.groupby(by='Species')

# %%
df.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df_groupby.mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# Species
# Iris-setosa       25.5          5.006         3.418          1.464  \
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
df_groupby.median()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# Species
# Iris-setosa       25.5            5.0           3.4           1.50  \
# Iris-versicolor   75.5            5.9           2.8           4.35
# Iris-virginica   125.5            6.5           3.0           5.55
#
#                  PetalWidthCm
# Species
# Iris-setosa               0.2
# Iris-versicolor           1.3
# Iris-virginica            2.0

# %%
df_groupby.std()
# Out:
#                        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# Species
# Iris-setosa      14.57738       0.352490      0.381024       0.173511  \
# Iris-versicolor  14.57738       0.516171      0.313798       0.469911
# Iris-virginica   14.57738       0.635880      0.322497       0.551895
#
#                  PetalWidthCm
# Species
# Iris-setosa          0.107210
# Iris-versicolor      0.197753
# Iris-virginica       0.274650

# %%
df_groupby.min()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa        1            4.3           2.3            1.0           0.1
# Iris-versicolor   51            4.9           2.0            3.0           1.0
# Iris-virginica   101            4.9           2.2            4.5           1.4

# %%
df_groupby.max()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       50            5.8           4.4            1.9           0.6
# Iris-versicolor  100            7.0           3.4            5.1           1.8
# Iris-virginica   150            7.9           3.8            6.9           2.5

# %%
df_groupby.var()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# Species
# Iris-setosa      212.5       0.124249      0.145180       0.030106  \
# Iris-versicolor  212.5       0.266433      0.098469       0.220816
# Iris-virginica   212.5       0.404343      0.104004       0.304588
#
#                  PetalWidthCm
# Species
# Iris-setosa          0.011494
# Iris-versicolor      0.039106
# Iris-virginica       0.075433

# %%
df_groupby.quantile()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# Species
# Iris-setosa       25.5            5.0           3.4           1.50  \
# Iris-versicolor   75.5            5.9           2.8           4.35
# Iris-virginica   125.5            6.5           3.0           5.55
#
#                  PetalWidthCm
# Species
# Iris-setosa               0.2
# Iris-versicolor           1.3
# Iris-virginica            2.0

# %%
df.groupby('Species').agg(['max','min','count','median','mean'])
# Out:
#                   Id                          SepalLengthCm
#                  max  min count median   mean           max  min count median
# Species
# Iris-setosa       50    1    50   25.5   25.5           5.8  4.3    50    5.0  \
# Iris-versicolor  100   51    50   75.5   75.5           7.0  4.9    50    5.9
# Iris-virginica   150  101    50  125.5  125.5           7.9  4.9    50    6.5
#
#                         ... PetalLengthCm
#                   mean  ...           max  min count median   mean
# Species                 ...
# Iris-setosa      5.006  ...           1.9  1.0    50   1.50  1.464  \
# Iris-versicolor  5.936  ...           5.1  3.0    50   4.35  4.260
# Iris-virginica   6.588  ...           6.9  4.5    50   5.55  5.552
#
#                 PetalWidthCm
#                          max  min count median   mean
# Species
# Iris-setosa              0.6  0.1    50    0.2  0.244
# Iris-versicolor          1.8  1.0    50    1.3  1.326
# ...

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
Iris_versicolor=df.loc[df.Species=='Iris-versicolor']

# %%
Iris_versicolor.min()
# Out:
# Id                            51
# SepalLengthCm                4.9
# SepalWidthCm                 2.0
# PetalLengthCm                3.0
# PetalWidthCm                 1.0
# Species          Iris-versicolor
# dtype: object

# %%
Iris_versicolor.mean(numeric_only = True)
# Out:
# Id               75.500
# SepalLengthCm     5.936
# SepalWidthCm      2.770
# PetalLengthCm     4.260
# PetalWidthCm      1.326
# dtype: float64

# %%
Iris_versicolor.mode()
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0    51            5.5           3.0            4.5           1.3  \
# 1    52            5.6           NaN            NaN           NaN
# 2    53            5.7           NaN            NaN           NaN
# 3    54            NaN           NaN            NaN           NaN
# 4    55            NaN           NaN            NaN           NaN
# 5    56            NaN           NaN            NaN           NaN
# 6    57            NaN           NaN            NaN           NaN
# 7    58            NaN           NaN            NaN           NaN
# 8    59            NaN           NaN            NaN           NaN
# 9    60            NaN           NaN            NaN           NaN
# 10   61            NaN           NaN            NaN           NaN
# 11   62            NaN           NaN            NaN           NaN
# 12   63            NaN           NaN            NaN           NaN
# ...

# %%
Iris_versicolor.median(numeric_only = True)
# Out:
# Id               75.50
# SepalLengthCm     5.90
# SepalWidthCm      2.80
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
Iris_versicolor.mean(numeric_only = True)

# %%
Iris_versicolor.quantile(0.75,numeric_only = True)
# Out:
# Id               87.75
# SepalLengthCm     6.30
# SepalWidthCm      3.00
# PetalLengthCm     4.60
# PetalWidthCm      1.50
# Name: 0.75, dtype: float64

# %%
Iris_setosa=df.loc[df.Species=='Iris-setosa']

# %%
Iris_setosa.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.3
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
Iris_virginica=df.loc[df.Species=='Iris-virginica']

# %%
df.Iris_virginica.min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1448\612165468.py in ?()
# ----> 1 df.Iris_virginica.min()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Iris_virginica'
